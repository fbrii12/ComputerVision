# %% [markdown]
# <a href="https://colab.research.google.com/github/fbrii12/ComputerVision/blob/main/2318068_Febri_Maulana_Rokhman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Import Library**

# %%
import cv2
import numpy as np
import pandas as pd
import os
from google.colab import drive

# %% [markdown]
# # **2. Mount Google Drive**

# %%
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/ComputerVision/EkstraksiFitur/gambar'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **3. Melakukan Konversi Citra BGR ke Grayscale**

# %%
import cv2

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/ComputerVision/EkstraksiFitur/gambar'

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Menentukan spesifikasi file citra yang akan digunakan, yaitu yang memiliki ekstensi.jpg, .jpeg, dan .png
    if file_name.endswith('.jpg') or file_name.endswith('.jpeg') or file_name.endswith('.png'):
        #Membaca file citra yang ada di dalam folder Google Drive
        image = cv2.imread(os.path.join(folder_path, file_name))
        #Melakukan konversi citra dari BGR menjadi Grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #Menyimpan dan mendefinisikan nama file citra hasil konversi ke dalam folder Google Drive
        cv2.imwrite(os.path.join(folder_path, f"grayscale_{file_name}"), grayscale_image)
        #Mencetak pesan berhasil mengkonversi citra
        print(f'File {file_name} berhasil diubah menjadi grayscale.')
# Out:
# File r0_103_100.jpg berhasil diubah menjadi grayscale.
# File r0_107_100.jpg berhasil diubah menjadi grayscale.
# File r0_111_100.jpg berhasil diubah menjadi grayscale.
# File r0_115_100.jpg berhasil diubah menjadi grayscale.
# File r0_119_100.jpg berhasil diubah menjadi grayscale.
# File r0_11_100.jpg berhasil diubah menjadi grayscale.
# File r0_123_100.jpg berhasil diubah menjadi grayscale.
# File r0_127_100.jpg berhasil diubah menjadi grayscale.
# File r0_131_100.jpg berhasil diubah menjadi grayscale.
# File r0_135_100.jpg berhasil diubah menjadi grayscale.
# File r0_139_100.jpg berhasil diubah menjadi grayscale.
# File r0_143_100.jpg berhasil diubah menjadi grayscale.
# File r0_147_100.jpg berhasil diubah menjadi grayscale.
# File r0_151_100.jpg berhasil diubah menjadi grayscale.
# File r0_155_100.jpg berhasil diubah menjadi grayscale.

# %% [markdown]
# # **4. Melakukan Ekstraksi Fitur Tekstur pada 15 Citra**

# %%
import os
#Melakukan import library opencv yang digunakan untuk melakukan konversi color space
import cv2
#Melakukan import library NumPy yang digunakan untuk membentuk objek N-dimensional array
import numpy as np
#Melakukan import graycomatrix untuk menghitung matriks co-occurance tingkat keabuan, dan graycoprops untuk menghitung properti tekstur dari GLCM dari library skimage.feature
from skimage.feature import graycomatrix, graycoprops
#Melakukan import library Pandas yang digunakan untuk membaca isi file excel
import pandas as pd

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/ComputerVision/EkstraksiFitur/gambar'
#Membuat variabel array kosong yang akan digunakan untuk menampung nilai fitur hasil ekstraksi
nilai_fitur = []

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Menentukan spesifikasi file citra yang akan digunakan, yaitu yang memiliki ekstensi.jpg, .jpeg, dan .png
    if file_name.endswith(".jpg") or file_name.endswith('.jpeg') or file_name.endswith(".png"):
        #Membaca file citra yang ada di dalam folder Google Drive
        image = cv2.imread(os.path.join(folder_path, file_name))
        #Melakukan konversi citra dari BGR menjadi Grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #Menghitung matriks co-occurance dari citra hasil konversi
        glcm = graycomatrix(grayscale_image, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4], symmetric=True, normed=True)
        #Menghitung rata-rata properti tekstur energi dari GLCM
        energi = graycoprops(glcm, 'energy').mean()
        #Menghitung rata-rata properti tekstur kontras dari GLCM
        kontras = graycoprops(glcm, 'contrast').mean()
        #Menghitung rata-rata properti tekstur korelasi dari GLCM
        korelasi = graycoprops(glcm, 'correlation').mean()
        #Menghitung rata-rata properti tekstur homogenitas dari GLCM
        homogenitas = graycoprops(glcm, 'homogeneity').mean()
        #Menampung nilai fitur ke dalam variabel array nilai_fitur
        nilai_fitur.append([file_name, energi, kontras, korelasi, homogenitas])

        #Mencetak nama file
        print(f"File {file_name}:")
        #Mencetak nilai energi
        print(f"Energi: {energi:.3f}")
        #Mencetak nilai kontras
        print(f"Kontras: {kontras:.3f}")
        #Mencetak nilai korelasi
        print(f"Korelasi: {korelasi:.3f}")
        #Mencetak nilai homogenitas
        print(f"Homogenitas: {homogenitas:.3f}")
    else:
        #Mencetak nama file jika bukan gambar
        print(f"Nama File: {file_name}")
# Out:
# File r0_103_100.jpg:
# Energi: 0.396
# Kontras: 585.826
# Korelasi: 0.976
# Homogenitas: 0.625
# File r0_107_100.jpg:
# Energi: 0.398
# Kontras: 544.196
# Korelasi: 0.977
# Homogenitas: 0.619
# File r0_111_100.jpg:
# Energi: 0.408
# Kontras: 527.990
# Korelasi: 0.978
# Homogenitas: 0.624
# File r0_115_100.jpg:
# Energi: 0.408
# Kontras: 527.221
# Korelasi: 0.978
# Homogenitas: 0.626
# File r0_119_100.jpg:
# Energi: 0.407
# Kontras: 513.569
# Korelasi: 0.978
# Homogenitas: 0.625
# File r0_11_100.jpg:
# Energi: 0.326
# Kontras: 528.348
# Korelasi: 0.977
# Homogenitas: 0.600
# File r0_123_100.jpg:
# Energi: 0.401
# Kontras: 524.381
# Korelasi: 0.978
# Homogenitas: 0.621
# File r0_127_100.jpg:
# Energi: 0.413
# Kontras: 525.802
# Korelasi: 0.977
# Homogenitas: 0.626
# File r0_131_100.jpg:
# Energi: 0.412
# Kontras: 497.917
# Korelasi: 0.979
# Homogenitas: 0.622
# File r0_135_100.jpg:
# Energi: 0.408
# Kontras: 502.592
# Korelasi: 0.978
# Homogenitas: 0.617
# File r0_139_100.jpg:
# Energi: 0.402
# Kontras: 500.315
# Korelasi: 0.978
# Homogenitas: 0.615
# File r0_143_100.jpg:
# Energi: 0.404
# Kontras: 504.543
# Korelasi: 0.978
# Homogenitas: 0.610
# File r0_147_100.jpg:
# Energi: 0.409
# Kontras: 508.363
# Korelasi: 0.978
# Homogenitas: 0.610
# File r0_151_100.jpg:
# Energi: 0.392
# Kontras: 509.022
# Korelasi: 0.977
# Homogenitas: 0.599
# File r0_155_100.jpg:
# Energi: 0.385
# Kontras: 497.503
# Korelasi: 0.977
# Homogenitas: 0.590
# File grayscale_r0_103_100.jpg:
# Energi: 0.349
# Kontras: 586.226
# Korelasi: 0.976
# Homogenitas: 0.589
# File grayscale_r0_107_100.jpg:
# Energi: 0.352
# Kontras: 544.871
# Korelasi: 0.977
# Homogenitas: 0.583
# File grayscale_r0_111_100.jpg:
# Energi: 0.359
# Kontras: 528.225
# Korelasi: 0.978
# Homogenitas: 0.586
# File grayscale_r0_115_100.jpg:
# Energi: 0.364
# Kontras: 528.747
# Korelasi: 0.978
# Homogenitas: 0.592
# File grayscale_r0_119_100.jpg:
# Energi: 0.361
# Kontras: 515.292
# Korelasi: 0.978
# Homogenitas: 0.590
# File grayscale_r0_11_100.jpg:
# Energi: 0.281
# Kontras: 528.081
# Korelasi: 0.977
# Homogenitas: 0.565
# File grayscale_r0_123_100.jpg:
# Energi: 0.369
# Kontras: 525.257
# Korelasi: 0.978
# Homogenitas: 0.592
# File grayscale_r0_127_100.jpg:
# Energi: 0.370
# Kontras: 526.889
# Korelasi: 0.977
# Homogenitas: 0.592
# File grayscale_r0_131_100.jpg:
# Energi: 0.366
# Kontras: 498.267
# Korelasi: 0.978
# Homogenitas: 0.586
# File grayscale_r0_135_100.jpg:
# Energi: 0.367
# Kontras: 503.047
# Korelasi: 0.978
# Homogenitas: 0.583
# File grayscale_r0_139_100.jpg:
# Energi: 0.361
# Kontras: 500.002
# Korelasi: 0.978
# Homogenitas: 0.582
# File grayscale_r0_143_100.jpg:
# Energi: 0.357
# Kontras: 505.435
# Korelasi: 0.978
# Homogenitas: 0.573
# File grayscale_r0_147_100.jpg:
# Energi: 0.358
# Kontras: 508.640
# Korelasi: 0.978
# Homogenitas: 0.570
# File grayscale_r0_151_100.jpg:
# Energi: 0.342
# Kontras: 509.159
# Korelasi: 0.977
# Homogenitas: 0.559
# File grayscale_r0_155_100.jpg:
# Energi: 0.336
# Kontras: 499.054
# Korelasi: 0.977
# Homogenitas: 0.555

# %% [markdown]
# # **5. Simpan ke CSV**

# %%
output_path = '/content/drive/MyDrive/ComputerVision/EkstraksiFitur/fitur_tekstur_15citra.csv'
df = pd.DataFrame(nilai_fitur, columns=['File Name', 'Energy', 'Contrast', 'Correlation', 'Homogeneity'])
df.to_csv(output_path, index=False)

print(f"\nFile CSV berhasil disimpan di: {output_path}")
# Out:
# File CSV berhasil disimpan di: /content/drive/MyDrive/ComputerVision/EkstraksiFitur/fitur_tekstur_15citra.csv

# %% [markdown]
# # **6. Simpan ke Excel**

# %%
# Simpan juga ke Excel
excel_path = '/content/drive/MyDrive/ComputerVision/EkstraksiFitur/fitur_tekstur_15citra.xlsx'
df.to_excel(excel_path, index=False)

print("File Excel juga berhasil disimpan!")
# Out:
# File Excel juga berhasil disimpan!
